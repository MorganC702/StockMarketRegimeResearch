# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import RobustScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    ConfusionMatrixDisplay,
    roc_auc_score,
)
from scipy.stats import uniform, loguniform

# -----------------------------
# 1. Load and Prepare Data
# -----------------------------
train_df = pd.read_csv("../data/generated_data/train.csv")
test_df = pd.read_csv("../data/generated_data/test.csv")

drop_cols = ["date"]
train_df = train_df.select_dtypes(include=np.number).drop(columns=drop_cols, errors="ignore")
test_df = test_df.select_dtypes(include=np.number).drop(columns=drop_cols, errors="ignore")

train_df['regime_today'] = train_df['regime']
test_df['regime_today'] = test_df['regime']

train_df['regime_t+3'] = train_df['regime'].shift(-3)
test_df['regime_t+3'] = test_df['regime'].shift(-3)

train_df = train_df.drop(columns=['regime']).dropna(subset=['regime_t+3'])
test_df = test_df.drop(columns=['regime']).dropna(subset=['regime_t+3'])

# -----------------------------
# 2. Feature / Target Split
# -----------------------------
X_train = train_df.drop(columns=['regime_t+3'])
y_train = train_df['regime_t+3'].astype(int) - 1

X_test = test_df.drop(columns=['regime_t+3'])
y_test = test_df['regime_t+3'].astype(int) - 1

# -----------------------------
# 3. Scale Features
# -----------------------------
scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# -----------------------------
# 4. MLPClassifier Optimization (Expanded Grid)
# -----------------------------
pipeline_mlp = Pipeline([
    ('clf', MLPClassifier(max_iter=20000))
])

param_distributions_mlp = {
    'clf__hidden_layer_sizes': [
        (64,), (128,), (256,),
        (64, 32), (128, 64), (256, 128),
        (128, 64, 32), (256, 128, 64)
    ],
    'clf__activation': ['relu', 'tanh', 'logistic'],
    'clf__solver': ['adam', 'sgd'],
    'clf__alpha': loguniform(1e-6, 1e-1),          # stronger reg search
    'clf__learning_rate_init': loguniform(1e-5, 1e-1),
    'clf__learning_rate': ['constant', 'adaptive'],
    'clf__early_stopping': [True],
    'clf__random_state': [42]
}

search_mlp = RandomizedSearchCV(
    estimator=pipeline_mlp,
    param_distributions=param_distributions_mlp,
    n_iter=150,   # much bigger search
    scoring='roc_auc_ovr',
    cv=5,
    n_jobs=-1,
    verbose=2,
    random_state=42
)

search_mlp.fit(X_train_scaled, y_train)

print("\n== Best MLP Params ==")
print(search_mlp.best_params_)
print(f"Best CV AUC (OvR): {search_mlp.best_score_:.4f}")

best_mlp = search_mlp.best_estimator_

# -----------------------------
# 5. Evaluate on Test Set
# -----------------------------
y_pred_test = best_mlp.predict(X_test_scaled)
y_test_proba = best_mlp.predict_proba(X_test_scaled)

print("\n== MLP — TEST Accuracy Report ==")
print(f"Accuracy: {accuracy_score(y_test, y_pred_test):.4f}")
print(classification_report(y_test, y_pred_test, digits=4))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_test, cmap="Blues", values_format="d")
plt.title("MLP — Test Confusion Matrix")
plt.tight_layout()
plt.show()

# Test AUC
auc_score = roc_auc_score(y_test, y_test_proba, multi_class='ovr')
print(f"Test Set AUC (OvR): {auc_score:.4f}")

# -----------------------------
# 6. Confidence-Based Decile Analysis
# -----------------------------
confidences = y_test_proba.max(axis=1)
y_pred = np.argmax(y_test_proba, axis=1)

eval_df = pd.DataFrame({
    "true": y_test + 1,
    "pred": y_pred + 1,
    "conf": confidences
})

eval_df["correct"] = (eval_df["true"] == eval_df["pred"]).astype(int)
eval_df = eval_df.sort_values("conf", ascending=False).reset_index(drop=True)

decile_results = []
n = len(eval_df)
total_correct = eval_df["correct"].sum()

for d in range(10, 110, 10):
    cutoff = int((d / 100) * n)
    subset = eval_df.iloc[:cutoff]
    n_samples = len(subset)
    n_correct = subset["correct"].sum()
    accuracy = n_correct / n_samples if n_samples > 0 else 0
    avg_conf = subset["conf"].mean() if n_samples > 0 else 0

    decile_results.append({
        "Top %": f"Top {d}%",
        "N Samples": n_samples,
        "Correct Predictions": n_correct,
        "Accuracy in Decile": round(accuracy, 3),
        "Avg Confidence": round(avg_conf, 3)
    })

decile_df = pd.DataFrame(decile_results)
print("\n== Confidence Decile Table ==")
print(decile_df)
# Out:
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# [CV] END clf__activation=logistic, clf__alpha=0.00016949768237884723, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.0006870614282613297, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=0.00016949768237884723, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.0006870614282613297, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=logistic, clf__alpha=0.00016949768237884723, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.0006870614282613297, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=0.00016949768237884723, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.0006870614282613297, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=0.00016949768237884723, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.0006870614282613297, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=logistic, clf__alpha=0.009609812947036401, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.013145103232150115, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=0.009609812947036401, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.013145103232150115, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=0.009609812947036401, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.013145103232150115, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=0.009609812947036401, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.013145103232150115, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=0.009609812947036401, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.013145103232150115, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=tanh, clf__alpha=8.111941985431925e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.00016480446427978953, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=8.111941985431925e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.00016480446427978953, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=8.111941985431925e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.00016480446427978953, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=8.111941985431925e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.00016480446427978953, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=0.00014445251022763054, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.0028016351587162596, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=8.111941985431925e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.00016480446427978953, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=0.00014445251022763054, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.0028016351587162596, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=0.00014445251022763054, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.0028016351587162596, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=0.00019069966103000456, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=6.290644294586152e-05, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=logistic, clf__alpha=1.2674255898937221e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=adaptive, clf__learning_rate_init=0.021368329072358756, clf__random_state=42, clf__solver=sgd; total time=   0.9s
# [CV] END clf__activation=logistic, clf__alpha=1.2674255898937221e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=adaptive, clf__learning_rate_init=0.021368329072358756, clf__random_state=42, clf__solver=sgd; total time=   0.9s
# [CV] END clf__activation=relu, clf__alpha=0.00014445251022763054, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.0028016351587162596, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=0.00014445251022763054, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.0028016351587162596, clf__random_state=42, clf__solver=sgd; total time=   0.3s
# [CV] END clf__activation=logistic, clf__alpha=0.00019069966103000456, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=6.290644294586152e-05, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=logistic, clf__alpha=1.2674255898937221e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=adaptive, clf__learning_rate_init=0.021368329072358756, clf__random_state=42, clf__solver=sgd; total time=   0.8s
# [CV] END clf__activation=logistic, clf__alpha=0.00019069966103000456, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=6.290644294586152e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=1.2674255898937221e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=adaptive, clf__learning_rate_init=0.021368329072358756, clf__random_state=42, clf__solver=sgd; total time=   1.1s
# [CV] END clf__activation=logistic, clf__alpha=0.00019069966103000456, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=6.290644294586152e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=0.00019069966103000456, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=6.290644294586152e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=1.2674255898937221e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=adaptive, clf__learning_rate_init=0.021368329072358756, clf__random_state=42, clf__solver=sgd; total time=   1.2s
# [CV] END clf__activation=relu, clf__alpha=1.707072883030666e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.809461967501571e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.055517216852447225, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.01712337597316398, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=1.707072883030666e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.809461967501571e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.055517216852447225, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.01712337597316398, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.055517216852447225, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.01712337597316398, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.055517216852447225, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.01712337597316398, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=1.707072883030666e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.809461967501571e-05, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=1.707072883030666e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.809461967501571e-05, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=0.055517216852447225, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.01712337597316398, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=3.0786517836196202e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.00057624872164786, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=3.0786517836196202e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.00057624872164786, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=3.0786517836196202e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.00057624872164786, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=relu, clf__alpha=1.707072883030666e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.809461967501571e-05, clf__random_state=42, clf__solver=adam; total time=   0.7s
# [CV] END clf__activation=tanh, clf__alpha=3.0786517836196202e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.00057624872164786, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=tanh, clf__alpha=0.0001335916680165183, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=adaptive, clf__learning_rate_init=0.0018655260217376823, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=3.0786517836196202e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.00057624872164786, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=tanh, clf__alpha=0.0001335916680165183, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=adaptive, clf__learning_rate_init=0.0018655260217376823, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=0.0001335916680165183, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=adaptive, clf__learning_rate_init=0.0018655260217376823, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=tanh, clf__alpha=0.0001335916680165183, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=adaptive, clf__learning_rate_init=0.0018655260217376823, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=tanh, clf__alpha=0.0001335916680165183, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=adaptive, clf__learning_rate_init=0.0018655260217376823, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=0.016271360716645866, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0003807158379249392, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=0.016271360716645866, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0003807158379249392, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=0.016271360716645866, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0003807158379249392, clf__random_state=42, clf__solver=sgd; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=0.0146546199050222, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0003666421832063722, clf__random_state=42, clf__solver=sgd; total time=   1.0s
# [CV] END clf__activation=relu, clf__alpha=0.0146546199050222, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0003666421832063722, clf__random_state=42, clf__solver=sgd; total time=   0.9s
# [CV] END clf__activation=logistic, clf__alpha=0.016271360716645866, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0003807158379249392, clf__random_state=42, clf__solver=sgd; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=0.0146546199050222, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0003666421832063722, clf__random_state=42, clf__solver=sgd; total time=   1.1s
# [CV] END clf__activation=relu, clf__alpha=0.06395288218539363, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=0.00975619429117457, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=0.0146546199050222, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0003666421832063722, clf__random_state=42, clf__solver=sgd; total time=   1.1s
# [CV] END clf__activation=relu, clf__alpha=0.06395288218539363, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=0.00975619429117457, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=0.016271360716645866, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0003807158379249392, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=relu, clf__alpha=0.0008585306974480481, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0026800135558226975, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=0.0146546199050222, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0003666421832063722, clf__random_state=42, clf__solver=sgd; total time=   1.2s
# [CV] END clf__activation=relu, clf__alpha=0.0008585306974480481, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0026800135558226975, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=0.06395288218539363, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=0.00975619429117457, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=relu, clf__alpha=0.06395288218539363, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=0.00975619429117457, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=relu, clf__alpha=0.0008585306974480481, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0026800135558226975, clf__random_state=42, clf__solver=adam; total time=   0.0s
# [CV] END clf__activation=relu, clf__alpha=0.0008585306974480481, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0026800135558226975, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=0.06395288218539363, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=0.00975619429117457, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=tanh, clf__alpha=0.004328724829857124, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0019132683954526475, clf__random_state=42, clf__solver=sgd; total time=   0.8s
# [CV] END clf__activation=relu, clf__alpha=3.029476085280708e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=constant, clf__learning_rate_init=1.1549033124221249e-05, clf__random_state=42, clf__solver=adam; total time=   0.0s
# [CV] END clf__activation=relu, clf__alpha=3.029476085280708e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=constant, clf__learning_rate_init=1.1549033124221249e-05, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=0.0008585306974480481, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0026800135558226975, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=3.029476085280708e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=constant, clf__learning_rate_init=1.1549033124221249e-05, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=3.029476085280708e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=constant, clf__learning_rate_init=1.1549033124221249e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=3.029476085280708e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=constant, clf__learning_rate_init=1.1549033124221249e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.004328724829857124, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0019132683954526475, clf__random_state=42, clf__solver=sgd; total time=   1.0s
# [CV] END clf__activation=tanh, clf__alpha=0.004328724829857124, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0019132683954526475, clf__random_state=42, clf__solver=sgd; total time=   1.1s
# [CV] END clf__activation=relu, clf__alpha=9.853225172032558e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.018274508859816022, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=relu, clf__alpha=9.853225172032558e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.018274508859816022, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=tanh, clf__alpha=0.004328724829857124, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0019132683954526475, clf__random_state=42, clf__solver=sgd; total time=   1.2s
# [CV] END clf__activation=tanh, clf__alpha=0.004328724829857124, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0019132683954526475, clf__random_state=42, clf__solver=sgd; total time=   1.2s
# [CV] END clf__activation=relu, clf__alpha=9.853225172032558e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.018274508859816022, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=9.853225172032558e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.018274508859816022, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=0.0089305396428793, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.0507228344067004, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=9.853225172032558e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.018274508859816022, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=0.037566296134528526, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0006277730916958048, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=logistic, clf__alpha=0.0089305396428793, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.0507228344067004, clf__random_state=42, clf__solver=sgd; total time=   0.3s
# [CV] END clf__activation=relu, clf__alpha=0.037566296134528526, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0006277730916958048, clf__random_state=42, clf__solver=adam; total time=   0.0s
# [CV] END clf__activation=logistic, clf__alpha=3.588488911386256e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.008287522363768155, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=logistic, clf__alpha=0.0089305396428793, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.0507228344067004, clf__random_state=42, clf__solver=sgd; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=3.588488911386256e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.008287522363768155, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.027293781650374743, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=3.0086868214458443e-05, clf__random_state=42, clf__solver=sgd; total time=   0.0s
# [CV] END clf__activation=tanh, clf__alpha=0.027293781650374743, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=3.0086868214458443e-05, clf__random_state=42, clf__solver=sgd; total time=   0.0s
# [CV] END clf__activation=relu, clf__alpha=0.037566296134528526, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0006277730916958048, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=relu, clf__alpha=0.037566296134528526, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0006277730916958048, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=0.027293781650374743, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=3.0086868214458443e-05, clf__random_state=42, clf__solver=sgd; total time=   0.0s
# [CV] END clf__activation=logistic, clf__alpha=0.0089305396428793, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.0507228344067004, clf__random_state=42, clf__solver=sgd; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=0.0089305396428793, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.0507228344067004, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=3.588488911386256e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.008287522363768155, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=0.027293781650374743, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=3.0086868214458443e-05, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=logistic, clf__alpha=0.006366859160799431, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=constant, clf__learning_rate_init=0.012130221181165156, clf__random_state=42, clf__solver=adam; total time=   0.0s
# [CV] END clf__activation=tanh, clf__alpha=0.027293781650374743, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=3.0086868214458443e-05, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=0.037566296134528526, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.0006277730916958048, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=3.588488911386256e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.008287522363768155, clf__random_state=42, clf__solver=sgd; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=0.006366859160799431, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=constant, clf__learning_rate_init=0.012130221181165156, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=3.588488911386256e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.008287522363768155, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=0.00041083188946999295, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=1.263794633808287e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=0.006366859160799431, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=constant, clf__learning_rate_init=0.012130221181165156, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=logistic, clf__alpha=1.43597185698781e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.00018089390092767128, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=logistic, clf__alpha=0.00041083188946999295, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=1.263794633808287e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=0.006366859160799431, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=constant, clf__learning_rate_init=0.012130221181165156, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=logistic, clf__alpha=0.00041083188946999295, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=1.263794633808287e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=0.006366859160799431, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=constant, clf__learning_rate_init=0.012130221181165156, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=0.00041083188946999295, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=1.263794633808287e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=1.43597185698781e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.00018089390092767128, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=1.43597185698781e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.00018089390092767128, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=1.43597185698781e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.00018089390092767128, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=0.00041083188946999295, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=1.263794633808287e-05, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=2.4260488932164474e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.414536876494478e-05, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=4.9734444557171384e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.001443325767880603, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=1.43597185698781e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.00018089390092767128, clf__random_state=42, clf__solver=sgd; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=2.4260488932164474e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.414536876494478e-05, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=4.9734444557171384e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.001443325767880603, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=0.01097998881780967, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.030608522106722488, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=0.01097998881780967, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.030608522106722488, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=2.4260488932164474e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.414536876494478e-05, clf__random_state=42, clf__solver=sgd; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=4.9734444557171384e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.001443325767880603, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=2.4260488932164474e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.414536876494478e-05, clf__random_state=42, clf__solver=sgd; total time=   0.3s
# [CV] END clf__activation=relu, clf__alpha=2.4260488932164474e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.414536876494478e-05, clf__random_state=42, clf__solver=sgd; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=0.01097998881780967, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.030608522106722488, clf__random_state=42, clf__solver=sgd; total time=   0.0s
# [CV] END clf__activation=tanh, clf__alpha=4.9734444557171384e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.001443325767880603, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=tanh, clf__alpha=0.01097998881780967, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.030608522106722488, clf__random_state=42, clf__solver=sgd; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=4.9734444557171384e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.001443325767880603, clf__random_state=42, clf__solver=adam; total time=   0.6s
# [CV] END clf__activation=logistic, clf__alpha=0.03420914404434175, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.003897269889874577, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=0.026085627877576924, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=3.07858974802593e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=logistic, clf__alpha=0.03420914404434175, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.003897269889874577, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=0.01097998881780967, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.030608522106722488, clf__random_state=42, clf__solver=sgd; total time=   0.3s
# [CV] END clf__activation=logistic, clf__alpha=0.03420914404434175, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.003897269889874577, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=0.026085627877576924, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=3.07858974802593e-05, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=0.03420914404434175, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.003897269889874577, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=0.03420914404434175, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=constant, clf__learning_rate_init=0.003897269889874577, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.026085627877576924, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=3.07858974802593e-05, clf__random_state=42, clf__solver=adam; total time=   0.6s
# [CV] END clf__activation=tanh, clf__alpha=0.026085627877576924, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=3.07858974802593e-05, clf__random_state=42, clf__solver=adam; total time=   0.9s
# [CV] END clf__activation=relu, clf__alpha=0.020121155449063854, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0011040511903162248, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=tanh, clf__alpha=1.2898495377182665e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=adaptive, clf__learning_rate_init=0.00022410971619109496, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=0.026085627877576924, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=3.07858974802593e-05, clf__random_state=42, clf__solver=adam; total time=   0.9s
# [CV] END clf__activation=relu, clf__alpha=0.020121155449063854, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0011040511903162248, clf__random_state=42, clf__solver=adam; total time=   0.7s
# [CV] END clf__activation=tanh, clf__alpha=1.2898495377182665e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=adaptive, clf__learning_rate_init=0.00022410971619109496, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=tanh, clf__alpha=1.2898495377182665e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=adaptive, clf__learning_rate_init=0.00022410971619109496, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=tanh, clf__alpha=1.2898495377182665e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=adaptive, clf__learning_rate_init=0.00022410971619109496, clf__random_state=42, clf__solver=adam; total time=   0.7s
# [CV] END clf__activation=relu, clf__alpha=0.020121155449063854, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0011040511903162248, clf__random_state=42, clf__solver=adam; total time=   0.8s
# [CV] END clf__activation=tanh, clf__alpha=1.2898495377182665e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=adaptive, clf__learning_rate_init=0.00022410971619109496, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=relu, clf__alpha=0.020121155449063854, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0011040511903162248, clf__random_state=42, clf__solver=adam; total time=   0.8s
# [CV] END clf__activation=relu, clf__alpha=0.020121155449063854, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.0011040511903162248, clf__random_state=42, clf__solver=adam; total time=   1.0s
# [CV] END clf__activation=logistic, clf__alpha=4.1306144511331714e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=0.006487477066058677, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=3.194416563600365e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=1.4045842344024695e-05, clf__random_state=42, clf__solver=adam; total time=   0.0s
# [CV] END clf__activation=logistic, clf__alpha=4.1306144511331714e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=0.006487477066058677, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=4.1306144511331714e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=0.006487477066058677, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=3.194416563600365e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=1.4045842344024695e-05, clf__random_state=42, clf__solver=adam; total time=   0.0s
# [CV] END clf__activation=logistic, clf__alpha=3.194416563600365e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=1.4045842344024695e-05, clf__random_state=42, clf__solver=adam; total time=   0.0s
# [CV] END clf__activation=tanh, clf__alpha=0.07226207258080496, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.00010165510266418732, clf__random_state=42, clf__solver=sgd; total time=   0.4s
# [CV] END clf__activation=logistic, clf__alpha=3.194416563600365e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=1.4045842344024695e-05, clf__random_state=42, clf__solver=adam; total time=   0.0s
# [CV] END clf__activation=tanh, clf__alpha=0.07226207258080496, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.00010165510266418732, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=4.1306144511331714e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=0.006487477066058677, clf__random_state=42, clf__solver=adam; total time=   0.7s
# [CV] END clf__activation=tanh, clf__alpha=0.07226207258080496, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.00010165510266418732, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=tanh, clf__alpha=0.07226207258080496, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.00010165510266418732, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=tanh, clf__alpha=0.07226207258080496, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=adaptive, clf__learning_rate_init=0.00010165510266418732, clf__random_state=42, clf__solver=sgd; total time=   0.8s
# [CV] END clf__activation=tanh, clf__alpha=0.00032613327839065595, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.00013019246714361573, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=1.576919244719753e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=constant, clf__learning_rate_init=0.0009074256288983858, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.00032613327839065595, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.00013019246714361573, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=logistic, clf__alpha=3.194416563600365e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=1.4045842344024695e-05, clf__random_state=42, clf__solver=adam; total time=   0.6s
# [CV] END clf__activation=tanh, clf__alpha=0.00032613327839065595, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.00013019246714361573, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=1.576919244719753e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=constant, clf__learning_rate_init=0.0009074256288983858, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=1.576919244719753e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=constant, clf__learning_rate_init=0.0009074256288983858, clf__random_state=42, clf__solver=sgd; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=0.00032613327839065595, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.00013019246714361573, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=4.1306144511331714e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=0.006487477066058677, clf__random_state=42, clf__solver=adam; total time=   1.2s
# [CV] END clf__activation=tanh, clf__alpha=1.622842443218897e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.011129571947046007, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=1.576919244719753e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=constant, clf__learning_rate_init=0.0009074256288983858, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.00032613327839065595, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.00013019246714361573, clf__random_state=42, clf__solver=adam; total time=   0.6s
# [CV] END clf__activation=relu, clf__alpha=1.576919244719753e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(128,), clf__learning_rate=constant, clf__learning_rate_init=0.0009074256288983858, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=1.622842443218897e-05, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.011129571947046007, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=0.004376044634724402, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=0.003382387201936216, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# ...
# [CV] END clf__activation=relu, clf__alpha=0.030474883181857374, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.004679839449773939, clf__random_state=42, clf__solver=sgd; total time=   0.3s
# [CV] END clf__activation=relu, clf__alpha=0.030474883181857374, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.004679839449773939, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=tanh, clf__alpha=7.674541190879913e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=3.0376902301221646e-05, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=0.030474883181857374, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.004679839449773939, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=logistic, clf__alpha=0.00010034654974261199, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=5.251327323591976e-05, clf__random_state=42, clf__solver=sgd; total time=   1.0s
# [CV] END clf__activation=relu, clf__alpha=9.150505661171652e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.739584301027366e-05, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=7.674541190879913e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=3.0376902301221646e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=9.150505661171652e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.739584301027366e-05, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=9.150505661171652e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.739584301027366e-05, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=9.150505661171652e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=4.739584301027366e-05, clf__random_state=42, clf__solver=sgd; total time=   0.4s
# [CV] END clf__activation=tanh, clf__alpha=7.674541190879913e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=3.0376902301221646e-05, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=7.674541190879913e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=3.0376902301221646e-05, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=0.02958600419406135, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.00020912119561112194, clf__random_state=42, clf__solver=adam; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=7.674541190879913e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64), clf__learning_rate=adaptive, clf__learning_rate_init=3.0376902301221646e-05, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.02958600419406135, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.00020912119561112194, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=0.02958600419406135, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.00020912119561112194, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=0.02958600419406135, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.00020912119561112194, clf__random_state=42, clf__solver=adam; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=2.8936961811418987e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.005638179113187202, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=6.093803046393268e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=1.0241889774147396e-05, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=6.093803046393268e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=1.0241889774147396e-05, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=relu, clf__alpha=2.8936961811418987e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.005638179113187202, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=6.093803046393268e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=1.0241889774147396e-05, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=tanh, clf__alpha=0.02958600419406135, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate=adaptive, clf__learning_rate_init=0.00020912119561112194, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=tanh, clf__alpha=6.093803046393268e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=1.0241889774147396e-05, clf__random_state=42, clf__solver=sgd; total time=   0.1s
# [CV] END clf__activation=tanh, clf__alpha=6.093803046393268e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128, 64), clf__learning_rate=constant, clf__learning_rate_init=1.0241889774147396e-05, clf__random_state=42, clf__solver=sgd; total time=   0.2s
# [CV] END clf__activation=relu, clf__alpha=2.8936961811418987e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.005638179113187202, clf__random_state=42, clf__solver=sgd; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=2.8936961811418987e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.005638179113187202, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=relu, clf__alpha=2.8936961811418987e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate=constant, clf__learning_rate_init=0.005638179113187202, clf__random_state=42, clf__solver=sgd; total time=   0.5s
# [CV] END clf__activation=relu, clf__alpha=2.6459707466663775e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.08811056446172458, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=relu, clf__alpha=2.6459707466663775e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.08811056446172458, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=2.6459707466663775e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.08811056446172458, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=relu, clf__alpha=2.6459707466663775e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.08811056446172458, clf__random_state=42, clf__solver=adam; total time=   0.5s
# [CV] END clf__activation=relu, clf__alpha=2.6459707466663775e-06, clf__early_stopping=True, clf__hidden_layer_sizes=(256,), clf__learning_rate=constant, clf__learning_rate_init=0.08811056446172458, clf__random_state=42, clf__solver=adam; total time=   0.7s
# [CV] END clf__activation=logistic, clf__alpha=0.04170698497369619, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=adaptive, clf__learning_rate_init=0.010960279662561795, clf__random_state=42, clf__solver=sgd; total time=   0.7s
# [CV] END clf__activation=tanh, clf__alpha=0.005462037665708608, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.00010226988730324317, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=tanh, clf__alpha=0.005462037665708608, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.00010226988730324317, clf__random_state=42, clf__solver=adam; total time=   0.4s
# [CV] END clf__activation=tanh, clf__alpha=0.005462037665708608, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.00010226988730324317, clf__random_state=42, clf__solver=adam; total time=   0.3s
# [CV] END clf__activation=tanh, clf__alpha=0.005462037665708608, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.00010226988730324317, clf__random_state=42, clf__solver=adam; total time=   0.7s
# [CV] END clf__activation=tanh, clf__alpha=0.005462037665708608, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.00010226988730324317, clf__random_state=42, clf__solver=adam; total time=   1.0s
# [CV] END clf__activation=logistic, clf__alpha=0.04170698497369619, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=adaptive, clf__learning_rate_init=0.010960279662561795, clf__random_state=42, clf__solver=sgd; total time=   1.1s
# [CV] END clf__activation=logistic, clf__alpha=0.04170698497369619, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=adaptive, clf__learning_rate_init=0.010960279662561795, clf__random_state=42, clf__solver=sgd; total time=   1.1s
# [CV] END clf__activation=logistic, clf__alpha=0.04170698497369619, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=adaptive, clf__learning_rate_init=0.010960279662561795, clf__random_state=42, clf__solver=sgd; total time=   1.3s
# [CV] END clf__activation=logistic, clf__alpha=0.02992500202287781, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.0013441692037498812, clf__random_state=42, clf__solver=adam; total time=   0.7s
# [CV] END clf__activation=logistic, clf__alpha=0.02992500202287781, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.0013441692037498812, clf__random_state=42, clf__solver=adam; total time=   0.8s
# [CV] END clf__activation=logistic, clf__alpha=0.02992500202287781, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.0013441692037498812, clf__random_state=42, clf__solver=adam; total time=   0.6s
# [CV] END clf__activation=logistic, clf__alpha=0.02992500202287781, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.0013441692037498812, clf__random_state=42, clf__solver=adam; total time=   0.6s
# [CV] END clf__activation=logistic, clf__alpha=0.04170698497369619, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=adaptive, clf__learning_rate_init=0.010960279662561795, clf__random_state=42, clf__solver=sgd; total time=   1.6s
# [CV] END clf__activation=logistic, clf__alpha=0.02992500202287781, clf__early_stopping=True, clf__hidden_layer_sizes=(256, 128), clf__learning_rate=constant, clf__learning_rate_init=0.0013441692037498812, clf__random_state=42, clf__solver=adam; total time=   1.0s
#
# == Best MLP Params ==
# {'clf__activation': 'logistic', 'clf__alpha': np.float64(4.1306144511331714e-05), 'clf__early_stopping': True, 'clf__hidden_layer_sizes': (256, 128, 64), 'clf__learning_rate': 'adaptive', 'clf__learning_rate_init': np.float64(0.006487477066058677), 'clf__random_state': 42, 'clf__solver': 'adam'}
# Best CV AUC (OvR): 0.7247
#
# == MLP — TEST Accuracy Report ==
# Accuracy: 0.3279
#               precision    recall  f1-score   support
#
#            0     0.2840    0.4792    0.3566        48
#            1     0.0000    0.0000    0.0000        31
#            2     0.0000    0.0000    0.0000        15
#            3     0.2037    0.3607    0.2604        61
#            4     0.0000    0.0000    0.0000        15
#            5     0.3091    0.2906    0.2996       117
#            6     0.3750    0.2727    0.3158        11
#            7     0.3478    0.3478    0.3478        46
#            8     0.0000    0.0000    0.0000        17
#            9     0.4571    0.4812    0.4689       133
#
#     accuracy                         0.3279       494
#    macro avg     0.1977    0.2232    0.2049       494
# weighted avg     0.2898    0.3279    0.3034       494
# /Users/morgancooper/data-science/MSDSResearchProjects/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/morgancooper/data-science/MSDSResearchProjects/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/morgancooper/data-science/MSDSResearchProjects/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Test Set AUC (OvR): 0.7054
#
# == Confidence Decile Table ==
#       Top %  N Samples  Correct Predictions  Accuracy in Decile  \
# 0   Top 10%         49                   29               0.592
# 1   Top 20%         98                   53               0.541
# 2   Top 30%        148                   70               0.473
# 3   Top 40%        197                   87               0.442
# 4   Top 50%        247                  102               0.413
# 5   Top 60%        296                  119               0.402
# 6   Top 70%        345                  129               0.374
# 7   Top 80%        395                  141               0.357
# 8   Top 90%        444                  149               0.336
# 9  Top 100%        494                  162               0.328
#
#    Avg Confidence
# 0           0.574
# 1           0.529
# 2           0.498
# 3           0.474
# 4           0.450
# 5           0.426
# 6           0.403
# 7           0.383
# 8           0.365
# 9           0.347
