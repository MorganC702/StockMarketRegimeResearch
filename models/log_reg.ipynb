# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    ConfusionMatrixDisplay,
    roc_auc_score
)
from scipy.stats import loguniform, uniform

# -----------------------------
# 1. Load and Prepare Data
# -----------------------------
train_df = pd.read_csv("../data/generated_data/train.csv")
test_df = pd.read_csv("../data/generated_data/test.csv")

drop_cols = ["date"]
train_df = train_df.select_dtypes(include=np.number).drop(columns=drop_cols, errors="ignore")
test_df = test_df.select_dtypes(include=np.number).drop(columns=drop_cols, errors="ignore")

train_df['regime_today'] = train_df['regime']
test_df['regime_today'] = test_df['regime']

train_df['regime_t+3'] = train_df['regime'].shift(-3)
test_df['regime_t+3'] = test_df['regime'].shift(-3)

train_df = train_df.drop(columns=['regime']).dropna(subset=['regime_t+3'])
test_df = test_df.drop(columns=['regime']).dropna(subset=['regime_t+3'])

# -----------------------------
# 2. Feature / Target Split
# -----------------------------
X_train = train_df.drop(columns=['regime_t+3'])
y_train = train_df['regime_t+3'].astype(int) - 1

X_test = test_df.drop(columns=['regime_t+3'])
y_test = test_df['regime_t+3'].astype(int) - 1

# -----------------------------
# 3. Scale Features
# -----------------------------
scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# -----------------------------
# 4. Logistic Regression Optimization
# -----------------------------
pipeline_logreg = Pipeline([
    ('clf', LogisticRegression( max_iter=10000))
])

# Conditional search space
param_distributions_logreg = [
    {   # L1 penalty (only saga supports multinomial)
        'clf__penalty': ['l1'],
        'clf__solver': ['saga'],
        'clf__C': loguniform(0.001, 10),
        'clf__l1_ratio': [None],
        'clf__random_state': [42]
    },
    {   # L2 penalty
        'clf__penalty': ['l2'],
        'clf__solver': ['lbfgs', 'newton-cg', 'sag', 'saga'],
        'clf__C': loguniform(0.001, 10),
        'clf__l1_ratio': [None],
        'clf__random_state': [42]
    },
    {   # Elastic Net
        'clf__penalty': ['elasticnet'],
        'clf__solver': ['saga'],
        'clf__C': loguniform(0.001, 10),
        'clf__l1_ratio': uniform(0, 1),
        'clf__random_state': [42]
    }
]



search_logreg = RandomizedSearchCV(
    estimator=pipeline_logreg,
    param_distributions=param_distributions_logreg,
    n_iter=50,
    scoring='roc_auc_ovr',
    cv=5,
    n_jobs=-1,
    verbose=2,
    random_state=42
)

search_logreg.fit(X_train_scaled, y_train)

print("\n== Best Logistic Regression Params ==")
print(search_logreg.best_params_)
print(f"Best CV AUC (OvR): {search_logreg.best_score_:.4f}")

best_logreg = search_logreg.best_estimator_

# -----------------------------
# 5. Evaluate on Test Set
# -----------------------------
y_pred_test = best_logreg.predict(X_test_scaled)
y_test_proba = best_logreg.predict_proba(X_test_scaled)

print("\n== Logistic Regression — TEST Accuracy Report ==")
print(f"Accuracy: {accuracy_score(y_test, y_pred_test):.4f}")
print(classification_report(y_test, y_pred_test, digits=4))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_test, cmap="Blues", values_format="d")
plt.title("LogReg — Test Confusion Matrix")
plt.tight_layout()
plt.show()

# Calculate Test AUC
auc_score = roc_auc_score(y_test, y_test_proba, multi_class='ovr')
print(f"Test Set AUC (OvR): {auc_score:.4f}")

# -----------------------------
# 6. Confidence-Based Decile Analysis
# -----------------------------
confidences = y_test_proba.max(axis=1)
y_pred = np.argmax(y_test_proba, axis=1)

# Build eval DataFrame
eval_df = pd.DataFrame({
    "true": y_test + 1,  # Reverse 0-indexing for readability
    "pred": y_pred + 1,
    "conf": confidences
})

eval_df["correct"] = (eval_df["true"] == eval_df["pred"]).astype(int)
eval_df = eval_df.sort_values("conf", ascending=False).reset_index(drop=True)

decile_results = []
n = len(eval_df)
total_correct = eval_df["correct"].sum()

for d in range(10, 110, 10):  # Deciles: 10% to 100%
    cutoff = int((d / 100) * n)
    subset = eval_df.iloc[:cutoff]
    n_samples = len(subset)
    n_correct = subset["correct"].sum()
    accuracy = n_correct / n_samples if n_samples > 0 else 0
    avg_conf = subset["conf"].mean() if n_samples > 0 else 0

    decile_results.append({
        "Top %": f"Top {d}%",
        "N Samples": n_samples,
        "Correct Predictions": n_correct,
        "Accuracy in Decile": round(accuracy, 3),
        "Avg Confidence": round(avg_conf, 3)
    })

decile_df = pd.DataFrame(decile_results)
print("\n== Confidence Decile Table ==")
print(decile_df)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END clf__C=0.24400607090817547, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  39.8s
# [CV] END clf__C=0.004207053950287938, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   3.4s
# [CV] END clf__C=0.24400607090817547, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  43.5s
# [CV] END clf__C=0.24400607090817547, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  44.4s
# [CV] END clf__C=0.24400607090817547, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  45.5s
# [CV] END clf__C=0.004207053950287938, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   3.1s
# [CV] END clf__C=0.004207053950287938, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   3.9s
# [CV] END clf__C=0.24400607090817547, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  47.9s
# [CV] END clf__C=0.004207053950287938, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   3.8s
# [CV] END clf__C=1.5352246941973489, clf__l1_ratio=0.1834347898661638, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  49.8s
# [CV] END clf__C=0.004207053950287938, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   3.4s
# [CV] END clf__C=1.5352246941973489, clf__l1_ratio=0.1834347898661638, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  53.2s
# [CV] END clf__C=0.0012087541473056963, clf__l1_ratio=0.9699098521619943, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   4.2s
# [CV] END clf__C=1.5352246941973489, clf__l1_ratio=0.1834347898661638, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  57.5s
# [CV] END clf__C=0.0012087541473056963, clf__l1_ratio=0.9699098521619943, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   3.9s
# [CV] END clf__C=0.0012087541473056963, clf__l1_ratio=0.9699098521619943, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   4.2s
# [CV] END clf__C=1.5352246941973489, clf__l1_ratio=0.1834347898661638, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  58.6s
# [CV] END clf__C=1.5352246941973489, clf__l1_ratio=0.1834347898661638, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  59.3s
# [CV] END clf__C=0.0012087541473056963, clf__l1_ratio=0.9699098521619943, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   4.5s
# [CV] END clf__C=0.0012087541473056963, clf__l1_ratio=0.9699098521619943, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   4.7s
# [CV] END clf__C=0.0070689749506246055, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   5.1s
# [CV] END clf__C=0.0070689749506246055, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   5.3s
# [CV] END clf__C=0.0070689749506246055, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   4.8s
# [CV] END clf__C=0.0070689749506246055, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   4.8s
# [CV] END clf__C=0.0070689749506246055, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   5.2s
# [CV] END clf__C=2.9154431891537547, clf__l1_ratio=0.6011150117432088, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  41.3s
# [CV] END clf__C=2.9154431891537547, clf__l1_ratio=0.6011150117432088, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  44.4s
# [CV] END clf__C=0.29507066707905333, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  30.0s
# [CV] END clf__C=2.9154431891537547, clf__l1_ratio=0.6011150117432088, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  48.1s
# [CV] END clf__C=2.9154431891537547, clf__l1_ratio=0.6011150117432088, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  51.1s
# [CV] END clf__C=2.9154431891537547, clf__l1_ratio=0.6011150117432088, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  50.9s
# [CV] END clf__C=0.29507066707905333, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  37.9s
# [CV] END clf__C=0.29507066707905333, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  36.8s
# [CV] END clf__C=0.29507066707905333, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  37.6s
# [CV] END clf__C=0.12561043700013558, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=  15.7s
# [CV] END clf__C=0.12561043700013558, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=  13.3s
# [CV] END clf__C=0.29507066707905333, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  40.9s
# [CV] END clf__C=0.12561043700013558, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=  16.3s
# [CV] END clf__C=0.12561043700013558, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=  16.1s
# [CV] END clf__C=0.014618962793704957, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  11.0s
# [CV] END clf__C=0.014618962793704957, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  12.8s
# [CV] END clf__C=0.12561043700013558, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=  16.3s
# [CV] END clf__C=0.014618962793704957, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  11.6s
# [CV] END clf__C=0.014618962793704957, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  18.0s
# [CV] END clf__C=0.03975977214318096, clf__l1_ratio=0.04666566321361543, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  18.6s
# [CV] END clf__C=0.014618962793704957, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  27.1s
# [CV] END clf__C=0.03975977214318096, clf__l1_ratio=0.04666566321361543, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  24.1s
# [CV] END clf__C=0.03975977214318096, clf__l1_ratio=0.04666566321361543, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  24.9s
# [CV] END clf__C=0.03975977214318096, clf__l1_ratio=0.04666566321361543, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  24.4s
# [CV] END clf__C=0.03975977214318096, clf__l1_ratio=0.04666566321361543, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  25.4s
# [CV] END clf__C=0.06672367170464207, clf__l1_ratio=0.7851759613930136, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  22.2s
# [CV] END clf__C=0.06672367170464207, clf__l1_ratio=0.7851759613930136, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  28.3s
# [CV] END clf__C=0.0015339162591163618, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   4.1s
# [CV] END clf__C=0.0015339162591163618, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   3.6s
# [CV] END clf__C=0.06672367170464207, clf__l1_ratio=0.7851759613930136, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  28.7s
# [CV] END clf__C=0.0015339162591163618, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   4.0s
# [CV] END clf__C=0.0015339162591163618, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   4.1s
# [CV] END clf__C=0.0015339162591163618, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   4.5s
# [CV] END clf__C=0.03387255565852149, clf__l1_ratio=0.9832308858067882, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  19.8s
# [CV] END clf__C=0.06672367170464207, clf__l1_ratio=0.7851759613930136, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  26.4s
# [CV] END clf__C=0.03387255565852149, clf__l1_ratio=0.9832308858067882, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  23.1s
# [CV] END clf__C=0.06672367170464207, clf__l1_ratio=0.7851759613930136, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  40.2s
# [CV] END clf__C=0.03387255565852149, clf__l1_ratio=0.9832308858067882, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  23.2s
# [CV] END clf__C=0.03387255565852149, clf__l1_ratio=0.9832308858067882, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  23.2s
# [CV] END clf__C=0.03387255565852149, clf__l1_ratio=0.9832308858067882, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  31.4s
# [CV] END clf__C=6.245139574743075, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   9.8s
# [CV] END clf__C=1.7123375973163988, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   1.1s
# [CV] END clf__C=1.7123375973163988, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   1.3s
# [CV] END clf__C=1.7123375973163988, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   1.0s
# [CV] END clf__C=6.245139574743075, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   8.6s
# [CV] END clf__C=1.7123375973163988, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   1.2s
# [CV] END clf__C=0.5262961031076743, clf__l1_ratio=0.450499251969543, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  20.0s
# [CV] END clf__C=6.245139574743075, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=  10.1s
# [CV] END clf__C=0.5262961031076743, clf__l1_ratio=0.450499251969543, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  22.4s
# [CV] END clf__C=1.7123375973163988, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   1.4s
# [CV] END clf__C=0.5262961031076743, clf__l1_ratio=0.450499251969543, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  22.6s
# [CV] END clf__C=0.002458603276328005, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   2.8s
# [CV] END clf__C=6.245139574743075, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=  11.0s
# [CV] END clf__C=0.002458603276328005, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   2.4s
# [CV] END clf__C=0.002458603276328005, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   2.6s
# [CV] END clf__C=0.002458603276328005, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   3.2s
# [CV] END clf__C=0.002458603276328005, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   2.9s
# [CV] END clf__C=0.5262961031076743, clf__l1_ratio=0.450499251969543, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  22.0s
# [CV] END clf__C=6.245139574743075, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=  10.6s
# [CV] END clf__C=0.5262961031076743, clf__l1_ratio=0.450499251969543, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  22.0s
# [CV] END clf__C=0.004936948694960458, clf__l1_ratio=0.3910606075732408, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   4.8s
# [CV] END clf__C=0.4467752817973907, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.2s
# [CV] END clf__C=0.4467752817973907, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.2s
# [CV] END clf__C=0.4467752817973907, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.1s
# [CV] END clf__C=0.4467752817973907, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.1s
# [CV] END clf__C=0.4467752817973907, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.2s
# [CV] END clf__C=0.12030178871154672, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.2s
# [CV] END clf__C=0.12030178871154672, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.1s
# [CV] END clf__C=0.12030178871154672, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.1s
# [CV] END clf__C=0.004936948694960458, clf__l1_ratio=0.3910606075732408, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   6.2s
# [CV] END clf__C=0.12030178871154672, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.1s
# [CV] END clf__C=0.12030178871154672, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.1s
# [CV] END clf__C=0.0013342990285187936, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.0s
# [CV] END clf__C=0.0013342990285187936, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.0s
# [CV] END clf__C=0.0013342990285187936, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.0s
# [CV] END clf__C=0.0013342990285187936, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.0s
# [CV] END clf__C=0.0013342990285187936, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.0s
# [CV] END clf__C=0.06295301484516132, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.0s
# [CV] END clf__C=0.06295301484516132, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.0s
# [CV] END clf__C=0.06295301484516132, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.0s
# [CV] END clf__C=0.06295301484516132, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.0s
# [CV] END clf__C=0.06295301484516132, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=newton-cg; total time=   0.0s
# [CV] END clf__C=0.004936948694960458, clf__l1_ratio=0.3910606075732408, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   5.3s
# [CV] END clf__C=0.004936948694960458, clf__l1_ratio=0.3910606075732408, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   7.2s
# [CV] END clf__C=0.004936948694960458, clf__l1_ratio=0.3910606075732408, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   6.9s
# [CV] END clf__C=5.089035297840714, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   6.7s
# [CV] END clf__C=0.5408216580718497, clf__l1_ratio=0.6099966577826209, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  16.2s
# [CV] END clf__C=5.089035297840714, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=  10.1s
# [CV] END clf__C=0.5408216580718497, clf__l1_ratio=0.6099966577826209, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  18.4s
# [CV] END clf__C=0.5408216580718497, clf__l1_ratio=0.6099966577826209, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  19.0s
# [CV] END clf__C=0.5408216580718497, clf__l1_ratio=0.6099966577826209, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  19.6s
# [CV] END clf__C=0.002259279742015696, clf__l1_ratio=0.1959828624191452, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   6.3s
# [CV] END clf__C=5.089035297840714, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=  11.0s
# [CV] END clf__C=0.5408216580718497, clf__l1_ratio=0.6099966577826209, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  20.3s
# [CV] END clf__C=0.002259279742015696, clf__l1_ratio=0.1959828624191452, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   4.8s
# [CV] END clf__C=0.002259279742015696, clf__l1_ratio=0.1959828624191452, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   4.7s
# [CV] END clf__C=5.089035297840714, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=  11.8s
# [CV] END clf__C=5.089035297840714, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=  15.1s
# [CV] END clf__C=0.002259279742015696, clf__l1_ratio=0.1959828624191452, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   5.8s
# [CV] END clf__C=0.002259279742015696, clf__l1_ratio=0.1959828624191452, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   5.8s
# [CV] END clf__C=0.03586816498627549, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  10.4s
# [CV] END clf__C=0.03586816498627549, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  12.0s
# [CV] END clf__C=0.03586816498627549, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  12.4s
# [CV] END clf__C=0.03586816498627549, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  14.1s
# [CV] END clf__C=6.993395623207715, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  20.7s
# [CV] END clf__C=0.1441346937111033, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   7.1s
# [CV] END clf__C=6.993395623207715, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  19.9s
# [CV] END clf__C=0.1441346937111033, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   7.9s
# [CV] END clf__C=0.03586816498627549, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  20.1s
# [CV] END clf__C=0.1441346937111033, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   6.1s
# [CV] END clf__C=6.993395623207715, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  23.3s
# [CV] END clf__C=6.993395623207715, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  23.8s
# [CV] END clf__C=6.993395623207715, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  24.0s
# [CV] END clf__C=0.0036618192203924276, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   1.8s
# [CV] END clf__C=0.1441346937111033, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   7.7s
# [CV] END clf__C=0.0036618192203924276, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   1.9s
# [CV] END clf__C=0.0036618192203924276, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   1.6s
# [CV] END clf__C=0.0036618192203924276, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   2.1s
# [CV] END clf__C=0.1441346937111033, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   7.6s
# [CV] END clf__C=0.0036618192203924276, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   1.9s
# [CV] END clf__C=7.261414516028836, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   8.7s
# [CV] END clf__C=7.261414516028836, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   8.1s
# [CV] END clf__C=7.261414516028836, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=   9.6s
# [CV] END clf__C=0.004582133690843357, clf__l1_ratio=0.01563640674119393, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   4.6s
# [CV] END clf__C=7.261414516028836, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=  10.0s
# [CV] END clf__C=0.004582133690843357, clf__l1_ratio=0.01563640674119393, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   5.6s
# [CV] END clf__C=7.261414516028836, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=saga; total time=  10.2s
# [CV] END clf__C=0.004582133690843357, clf__l1_ratio=0.01563640674119393, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   4.6s
# [CV] END clf__C=0.004582133690843357, clf__l1_ratio=0.01563640674119393, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   5.7s
# [CV] END clf__C=0.004582133690843357, clf__l1_ratio=0.01563640674119393, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   6.7s
# [CV] END clf__C=1.2273800987852967, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  17.1s
# [CV] END clf__C=1.2273800987852967, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  19.1s
# [CV] END clf__C=1.2273800987852967, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  20.5s
# [CV] END clf__C=1.8274508859816028, clf__l1_ratio=0.7068573438476171, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  18.1s
# [CV] END clf__C=1.8274508859816028, clf__l1_ratio=0.7068573438476171, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  19.6s
# [CV] END clf__C=1.2273800987852967, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  22.1s
# [CV] END clf__C=1.8274508859816028, clf__l1_ratio=0.7068573438476171, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  21.7s
# [CV] END clf__C=0.02715581955282941, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   0.4s
# [CV] END clf__C=0.02715581955282941, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   0.2s
# [CV] END clf__C=0.02715581955282941, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   0.2s
# [CV] END clf__C=1.2273800987852967, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  22.3s
# [CV] END clf__C=0.02715581955282941, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   0.3s
# [CV] END clf__C=0.02715581955282941, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   0.3s
# [CV] END clf__C=1.8274508859816028, clf__l1_ratio=0.7068573438476171, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  24.0s
# [CV] END clf__C=1.8274508859816028, clf__l1_ratio=0.7068573438476171, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  24.9s
# [CV] END clf__C=1.4477786306928666, clf__l1_ratio=0.6059599747810114, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  29.6s
# [CV] END clf__C=1.4477786306928666, clf__l1_ratio=0.6059599747810114, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  29.8s
# [CV] END clf__C=0.0017956984225677636, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   3.5s
# [CV] END clf__C=1.4477786306928666, clf__l1_ratio=0.6059599747810114, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  33.3s
# [CV] END clf__C=0.0017956984225677636, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   2.9s
# [CV] END clf__C=0.0017956984225677636, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   3.5s
# [CV] END clf__C=0.0017956984225677636, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   3.3s
# [CV] END clf__C=0.0017956984225677636, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   3.7s
# [CV] END clf__C=2.512779099948728, clf__l1_ratio=0.4494506741382034, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  33.7s
# [CV] END clf__C=1.4477786306928666, clf__l1_ratio=0.6059599747810114, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  38.4s
# [CV] END clf__C=2.512779099948728, clf__l1_ratio=0.4494506741382034, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  36.2s
# [CV] END clf__C=1.4477786306928666, clf__l1_ratio=0.6059599747810114, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  38.9s
# [CV] END clf__C=3.53875886477924, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   3.3s
# [CV] END clf__C=3.53875886477924, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   3.5s
# [CV] END clf__C=2.512779099948728, clf__l1_ratio=0.4494506741382034, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  40.9s
# [CV] END clf__C=3.53875886477924, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   2.5s
# [CV] END clf__C=3.53875886477924, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   3.1s
# [CV] END clf__C=3.53875886477924, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   2.8s
# [CV] END clf__C=0.003008686821445846, clf__l1_ratio=0.713244787222995, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   2.4s
# [CV] END clf__C=2.512779099948728, clf__l1_ratio=0.4494506741382034, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  41.7s
# [CV] END clf__C=0.003008686821445846, clf__l1_ratio=0.713244787222995, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   2.4s
# [CV] END clf__C=2.512779099948728, clf__l1_ratio=0.4494506741382034, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  41.8s
# [CV] END clf__C=0.003008686821445846, clf__l1_ratio=0.713244787222995, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   2.7s
# [CV] END clf__C=0.003008686821445846, clf__l1_ratio=0.713244787222995, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   2.2s
# [CV] END clf__C=0.003008686821445846, clf__l1_ratio=0.713244787222995, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   2.7s
# [CV] END clf__C=0.4735490946578582, clf__l1_ratio=0.6659223566174967, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  21.3s
# [CV] END clf__C=0.4735490946578582, clf__l1_ratio=0.6659223566174967, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  24.9s
# [CV] END clf__C=0.4735490946578582, clf__l1_ratio=0.6659223566174967, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  24.9s
# [CV] END clf__C=0.4735490946578582, clf__l1_ratio=0.6659223566174967, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  23.9s
# [CV] END clf__C=0.4735490946578582, clf__l1_ratio=0.6659223566174967, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  24.7s
# [CV] END clf__C=0.7707580772445938, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  17.0s
# [CV] END clf__C=0.7707580772445938, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  19.6s
# [CV] END clf__C=0.7707580772445938, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  20.4s
# [CV] END clf__C=0.7707580772445938, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  20.8s
# [CV] END clf__C=0.7707580772445938, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  21.7s
# [CV] END clf__C=1.2130221181165162, clf__l1_ratio=0.49379559636439074, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  18.5s
# [CV] END clf__C=0.0012637946338082875, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   0.2s
# [CV] END clf__C=0.0012637946338082875, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   0.1s
# [CV] END clf__C=0.0012637946338082875, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   0.2s
# [CV] END clf__C=1.2130221181165162, clf__l1_ratio=0.49379559636439074, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  20.5s
# [CV] END clf__C=0.0012637946338082875, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   0.1s
# [CV] END clf__C=0.0012637946338082875, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=lbfgs; total time=   0.2s
# [CV] END clf__C=0.0013357240411974098, clf__l1_ratio=0.6364104112637804, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   1.9s
# [CV] END clf__C=1.2130221181165162, clf__l1_ratio=0.49379559636439074, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  21.9s
# [CV] END clf__C=0.0013357240411974098, clf__l1_ratio=0.6364104112637804, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   2.0s
# [CV] END clf__C=0.0013357240411974098, clf__l1_ratio=0.6364104112637804, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   1.8s
# [CV] END clf__C=0.0013357240411974098, clf__l1_ratio=0.6364104112637804, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   2.1s
# [CV] END clf__C=0.0013357240411974098, clf__l1_ratio=0.6364104112637804, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   2.0s
# [CV] END clf__C=1.2130221181165162, clf__l1_ratio=0.49379559636439074, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  22.3s
# [CV] END clf__C=0.696067823913519, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  18.8s
# [CV] END clf__C=1.2130221181165162, clf__l1_ratio=0.49379559636439074, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=  22.9s
# [CV] END clf__C=0.696067823913519, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  16.3s
# [CV] END clf__C=0.0036084925884026665, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   1.6s
# [CV] END clf__C=0.0036084925884026665, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   1.8s
# [CV] END clf__C=0.696067823913519, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  19.4s
# [CV] END clf__C=0.0036084925884026665, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   1.5s
# [CV] END clf__C=0.0036084925884026665, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   1.6s
# [CV] END clf__C=0.0036084925884026665, clf__l1_ratio=None, clf__penalty=l2, clf__random_state=42, clf__solver=sag; total time=   1.7s
# [CV] END clf__C=0.696067823913519, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  19.0s
# [CV] END clf__C=0.696067823913519, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  20.4s
# [CV] END clf__C=0.1082138291061399, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  11.6s
# [CV] END clf__C=0.008226074946221037, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   2.4s
# [CV] END clf__C=0.1082138291061399, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  14.7s
# [CV] END clf__C=0.1082138291061399, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  14.5s
# [CV] END clf__C=0.008226074946221037, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   2.9s
# [CV] END clf__C=0.008226074946221037, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   3.3s
# [CV] END clf__C=0.1082138291061399, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  13.9s
# [CV] END clf__C=0.008226074946221037, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   4.1s
# [CV] END clf__C=0.008226074946221037, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=   3.7s
# [CV] END clf__C=0.14433257678806036, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  13.2s
# [CV] END clf__C=0.14433257678806036, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  14.5s
# [CV] END clf__C=0.14433257678806036, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  15.5s
# [CV] END clf__C=0.014421346497969485, clf__l1_ratio=0.16122128725400442, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   6.4s
# [CV] END clf__C=0.014421346497969485, clf__l1_ratio=0.16122128725400442, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   6.3s
# [CV] END clf__C=0.014421346497969485, clf__l1_ratio=0.16122128725400442, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   5.9s
# [CV] END clf__C=0.14433257678806036, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  14.1s
# [CV] END clf__C=0.014421346497969485, clf__l1_ratio=0.16122128725400442, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   5.6s
# [CV] END clf__C=0.014421346497969485, clf__l1_ratio=0.16122128725400442, clf__penalty=elasticnet, clf__random_state=42, clf__solver=saga; total time=   6.0s
# [CV] END clf__C=0.1082138291061399, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  24.9s
# [CV] END clf__C=0.14433257678806036, clf__l1_ratio=None, clf__penalty=l1, clf__random_state=42, clf__solver=saga; total time=  19.8s
#
# == Best Logistic Regression Params ==
# {'clf__C': np.float64(0.0013342990285187936), 'clf__l1_ratio': None, 'clf__penalty': 'l2', 'clf__random_state': 42, 'clf__solver': 'newton-cg'}
# Best CV AUC (OvR): 0.6981
#
# == Logistic Regression — TEST Accuracy Report ==
# Accuracy: 0.3320
#               precision    recall  f1-score   support
#
#            0     0.2500    0.5625    0.3462        48
#            1     0.0000    0.0000    0.0000        31
#            2     0.0000    0.0000    0.0000        15
#            3     0.1667    0.0164    0.0299        61
#            4     0.0000    0.0000    0.0000        15
#            5     0.3333    0.5812    0.4237       117
#            6     0.3333    0.0909    0.1429        11
#            7     0.4091    0.1957    0.2647        46
#            8     0.0000    0.0000    0.0000        17
#            9     0.3946    0.4361    0.4143       133
#
#     accuracy                         0.3320       494
#    macro avg     0.1887    0.1883    0.1622       494
# weighted avg     0.2756    0.3320    0.2770       494
# /Users/morgancooper/data-science/MSDSResearchProjects/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/morgancooper/data-science/MSDSResearchProjects/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/morgancooper/data-science/MSDSResearchProjects/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Test Set AUC (OvR): 0.6775
#
# == Confidence Decile Table ==
#       Top %  N Samples  Correct Predictions  Accuracy in Decile  \
# 0   Top 10%         49                   33               0.673
# 1   Top 20%         98                   50               0.510
# 2   Top 30%        148                   68               0.459
# 3   Top 40%        197                   86               0.437
# 4   Top 50%        247                   97               0.393
# 5   Top 60%        296                  109               0.368
# 6   Top 70%        345                  120               0.348
# 7   Top 80%        395                  134               0.339
# 8   Top 90%        444                  150               0.338
# 9  Top 100%        494                  164               0.332
#
#    Avg Confidence
# 0           0.364
# 1           0.322
# 2           0.300
# 3           0.285
# 4           0.273
# 5           0.264
# 6           0.255
# 7           0.247
# 8           0.240
# 9           0.232
