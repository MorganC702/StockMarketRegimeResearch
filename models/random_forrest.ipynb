# %%
import sys 
sys.path.append('..')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    ConfusionMatrixDisplay,
    roc_auc_score,
)
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint, uniform

# -----------------------------
# 1. Load and Prepare Data
# -----------------------------
train_df = pd.read_csv("../data/generated_data/train.csv")
test_df = pd.read_csv("../data/generated_data/test.csv")

drop_cols = ["date"]
train_df = train_df.select_dtypes(include=np.number).drop(columns=drop_cols, errors="ignore")
test_df = test_df.select_dtypes(include=np.number).drop(columns=drop_cols, errors="ignore")

train_df['regime_today'] = train_df['regime']
test_df['regime_today'] = test_df['regime']

train_df['regime_t+3'] = train_df['regime'].shift(-3)
test_df['regime_t+3'] = test_df['regime'].shift(-3)

train_df = train_df.drop(columns=['regime']).dropna(subset=['regime_t+3'])
test_df = test_df.drop(columns=['regime']).dropna(subset=['regime_t+3'])

# -----------------------------
# 2. Feature / Target Split
# -----------------------------
X_train = train_df.drop(columns=['regime_t+3'])
y_train = train_df['regime_t+3'].astype(int) - 1  # 0-index for RF

X_test = test_df.drop(columns=['regime_t+3'])
y_test = test_df['regime_t+3'].astype(int) - 1

# -----------------------------
# 3. Scale Features
# -----------------------------
scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# -----------------------------
# 4. Random Forest Optimization
# -----------------------------
pipeline_rf = Pipeline([
    ('clf', RandomForestClassifier())
])

param_distributions_rf = {
    'clf__n_estimators': randint(100, 500),
    'clf__max_depth': [None, 10, 20, 30, 50],
    'clf__min_samples_split': randint(2, 10),
    'clf__min_samples_leaf': randint(1, 5),
    'clf__max_features': ['sqrt', 'log2', None],
    'clf__bootstrap': [True, False],
    'clf__class_weight': [None, 'balanced'],
    'clf__random_state': [42],
}

search_rf = RandomizedSearchCV(
    estimator=pipeline_rf,
    param_distributions=param_distributions_rf,
    n_iter=100,
    scoring='roc_auc_ovr',
    cv=5,
    n_jobs=-1,
    verbose=2,
    random_state=42
)

search_rf.fit(X_train_scaled, y_train)

print("\n== Best Random Forest Params ==")
print(search_rf.best_params_)
print(f"Best CV AUC (OvR): {search_rf.best_score_:.4f}")

best_rf = search_rf.best_estimator_

# -----------------------------
# 5. Evaluate on Test Set
# -----------------------------
y_pred_test = best_rf.predict(X_test_scaled)
y_test_proba = best_rf.predict_proba(X_test_scaled)

print("\n== Random Forest — TEST Accuracy Report ==")
print(f"Accuracy: {accuracy_score(y_test, y_pred_test):.4f}")
print(classification_report(y_test, y_pred_test, digits=4))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_test, cmap="Blues", values_format="d")
plt.title("Random Forest — Test Confusion Matrix")
plt.tight_layout()
plt.show()

# Test AUC
auc_score = roc_auc_score(y_test, y_test_proba, multi_class='ovr')
print(f"Test Set AUC (OvR): {auc_score:.4f}")

# -----------------------------
# 6. Confidence-Based Decile Analysis
# -----------------------------
confidences = y_test_proba.max(axis=1)
y_pred = np.argmax(y_test_proba, axis=1)

eval_df = pd.DataFrame({
    "true": y_test + 1,
    "pred": y_pred + 1,
    "conf": confidences
})

eval_df["correct"] = (eval_df["true"] == eval_df["pred"]).astype(int)
eval_df = eval_df.sort_values("conf", ascending=False).reset_index(drop=True)

decile_results = []
n = len(eval_df)
total_correct = eval_df["correct"].sum()

for d in range(10, 110, 10):
    cutoff = int((d / 100) * n)
    subset = eval_df.iloc[:cutoff]
    n_samples = len(subset)
    n_correct = subset["correct"].sum()
    accuracy = n_correct / n_samples if n_samples > 0 else 0
    avg_conf = subset["conf"].mean() if n_samples > 0 else 0

    decile_results.append({
        "Top %": f"Top {d}%",
        "N Samples": n_samples,
        "Correct Predictions": n_correct,
        "Accuracy in Decile": round(accuracy, 3),
        "Avg Confidence": round(avg_conf, 3)
    })

decile_df = pd.DataFrame(decile_results)
print("\n== Confidence Decile Table ==")
print(decile_df)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=4, clf__n_estimators=187, clf__random_state=42; total time=  15.9s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=4, clf__n_estimators=187, clf__random_state=42; total time=  15.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=4, clf__n_estimators=187, clf__random_state=42; total time=  15.9s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=4, clf__n_estimators=187, clf__random_state=42; total time=  16.2s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=4, clf__n_estimators=187, clf__random_state=42; total time=  16.6s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=443, clf__random_state=42; total time=   8.5s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=443, clf__random_state=42; total time=   8.2s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=443, clf__random_state=42; total time=   8.7s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=443, clf__random_state=42; total time=   8.8s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=443, clf__random_state=42; total time=   8.6s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=288, clf__random_state=42; total time=  30.0s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=288, clf__random_state=42; total time=  30.6s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=288, clf__random_state=42; total time=  30.8s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=288, clf__random_state=42; total time=  31.4s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=288, clf__random_state=42; total time=  31.7s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=158, clf__random_state=42; total time=   6.9s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=158, clf__random_state=42; total time=   7.0s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=158, clf__random_state=42; total time=   7.2s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=158, clf__random_state=42; total time=   7.1s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=158, clf__random_state=42; total time=   6.9s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=413, clf__random_state=42; total time=  16.7s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=413, clf__random_state=42; total time=  17.1s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=413, clf__random_state=42; total time=  17.2s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=413, clf__random_state=42; total time=  16.6s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=413, clf__random_state=42; total time=  16.8s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=2, clf__min_samples_split=7, clf__n_estimators=274, clf__random_state=42; total time=  33.9s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=2, clf__min_samples_split=7, clf__n_estimators=274, clf__random_state=42; total time=  32.9s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=2, clf__min_samples_split=7, clf__n_estimators=274, clf__random_state=42; total time=  33.0s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=2, clf__min_samples_split=7, clf__n_estimators=274, clf__random_state=42; total time=  34.9s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=2, clf__min_samples_split=7, clf__n_estimators=274, clf__random_state=42; total time=  34.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=3, clf__n_estimators=487, clf__random_state=42; total time=   6.3s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=9, clf__n_estimators=230, clf__random_state=42; total time=  36.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=3, clf__n_estimators=487, clf__random_state=42; total time=   7.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=3, clf__n_estimators=487, clf__random_state=42; total time=   7.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=3, clf__n_estimators=487, clf__random_state=42; total time=   7.4s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=152, clf__random_state=42; total time=   2.7s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=3, clf__n_estimators=487, clf__random_state=42; total time=   8.5s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=9, clf__n_estimators=230, clf__random_state=42; total time=  39.4s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=152, clf__random_state=42; total time=   2.7s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=152, clf__random_state=42; total time=   2.8s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=9, clf__n_estimators=230, clf__random_state=42; total time=  40.7s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=152, clf__random_state=42; total time=   2.9s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=152, clf__random_state=42; total time=   2.9s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=101, clf__random_state=42; total time=   2.0s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=9, clf__n_estimators=230, clf__random_state=42; total time=  42.2s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=101, clf__random_state=42; total time=   1.9s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=101, clf__random_state=42; total time=   2.1s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=9, clf__n_estimators=230, clf__random_state=42; total time=  43.4s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=101, clf__random_state=42; total time=   2.1s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=5, clf__n_estimators=101, clf__random_state=42; total time=   2.2s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=317, clf__random_state=42; total time=   9.5s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=317, clf__random_state=42; total time=  10.7s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=317, clf__random_state=42; total time=  11.1s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=317, clf__random_state=42; total time=  10.4s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=317, clf__random_state=42; total time=  10.7s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=7, clf__n_estimators=450, clf__random_state=42; total time=  12.1s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=7, clf__n_estimators=450, clf__random_state=42; total time=  11.7s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=7, clf__n_estimators=450, clf__random_state=42; total time=  11.4s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=7, clf__n_estimators=450, clf__random_state=42; total time=  11.9s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=7, clf__n_estimators=450, clf__random_state=42; total time=  11.2s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=9, clf__n_estimators=312, clf__random_state=42; total time=   9.6s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=9, clf__n_estimators=312, clf__random_state=42; total time=   9.7s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=9, clf__n_estimators=312, clf__random_state=42; total time=   9.1s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=9, clf__n_estimators=312, clf__random_state=42; total time=   9.5s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=9, clf__n_estimators=312, clf__random_state=42; total time=   9.7s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=8, clf__n_estimators=363, clf__random_state=42; total time= 1.1min
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=6, clf__n_estimators=114, clf__random_state=42; total time=   3.0s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=8, clf__n_estimators=363, clf__random_state=42; total time= 1.1min
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=8, clf__n_estimators=363, clf__random_state=42; total time= 1.1min
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=6, clf__n_estimators=114, clf__random_state=42; total time=   3.5s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=6, clf__n_estimators=114, clf__random_state=42; total time=   3.6s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=6, clf__n_estimators=114, clf__random_state=42; total time=   3.4s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=8, clf__n_estimators=363, clf__random_state=42; total time= 1.2min
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=8, clf__n_estimators=363, clf__random_state=42; total time= 1.2min
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=6, clf__n_estimators=114, clf__random_state=42; total time=   3.4s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=316, clf__random_state=42; total time=  51.9s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=316, clf__random_state=42; total time=  54.2s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=316, clf__random_state=42; total time=  52.5s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=316, clf__random_state=42; total time=  54.6s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=316, clf__random_state=42; total time=  55.0s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=228, clf__random_state=42; total time=  26.4s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=228, clf__random_state=42; total time=  26.0s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=228, clf__random_state=42; total time=  27.3s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=8, clf__n_estimators=140, clf__random_state=42; total time=   2.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=228, clf__random_state=42; total time=  26.1s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=228, clf__random_state=42; total time=  27.2s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=8, clf__n_estimators=140, clf__random_state=42; total time=   3.0s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=8, clf__n_estimators=140, clf__random_state=42; total time=   2.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=8, clf__n_estimators=140, clf__random_state=42; total time=   2.9s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=8, clf__n_estimators=140, clf__random_state=42; total time=   2.9s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=161, clf__random_state=42; total time=   3.9s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=161, clf__random_state=42; total time=   3.5s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=161, clf__random_state=42; total time=   3.6s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=161, clf__random_state=42; total time=   3.6s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=161, clf__random_state=42; total time=   3.4s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=3, clf__min_samples_split=4, clf__n_estimators=326, clf__random_state=42; total time=   6.3s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=3, clf__min_samples_split=4, clf__n_estimators=326, clf__random_state=42; total time=   6.0s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=3, clf__min_samples_split=4, clf__n_estimators=326, clf__random_state=42; total time=   6.1s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=3, clf__min_samples_split=4, clf__n_estimators=326, clf__random_state=42; total time=   6.3s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=3, clf__min_samples_split=4, clf__n_estimators=326, clf__random_state=42; total time=   6.3s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=354, clf__random_state=42; total time=   6.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=354, clf__random_state=42; total time=   6.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=354, clf__random_state=42; total time=   7.2s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=354, clf__random_state=42; total time=   7.2s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=3, clf__n_estimators=354, clf__random_state=42; total time=   7.4s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=8, clf__n_estimators=445, clf__random_state=42; total time=  11.5s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=8, clf__n_estimators=445, clf__random_state=42; total time=  11.4s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=8, clf__n_estimators=445, clf__random_state=42; total time=  12.0s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=8, clf__n_estimators=445, clf__random_state=42; total time=  11.9s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=8, clf__n_estimators=445, clf__random_state=42; total time=  12.3s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=262, clf__random_state=42; total time=  45.1s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=262, clf__random_state=42; total time=  45.7s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=262, clf__random_state=42; total time=  46.6s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=330, clf__random_state=42; total time=   4.5s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=262, clf__random_state=42; total time=  48.3s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=330, clf__random_state=42; total time=   4.6s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=262, clf__random_state=42; total time=  51.3s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=330, clf__random_state=42; total time=   5.1s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=330, clf__random_state=42; total time=   5.1s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=330, clf__random_state=42; total time=   4.1s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=6, clf__n_estimators=259, clf__random_state=42; total time=   4.4s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=6, clf__n_estimators=259, clf__random_state=42; total time=   4.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=6, clf__n_estimators=259, clf__random_state=42; total time=   4.4s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=3, clf__n_estimators=269, clf__random_state=42; total time=   3.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=6, clf__n_estimators=259, clf__random_state=42; total time=   4.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=6, clf__n_estimators=259, clf__random_state=42; total time=   4.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=3, clf__n_estimators=269, clf__random_state=42; total time=   3.5s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=127, clf__random_state=42; total time=   2.1s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=127, clf__random_state=42; total time=   2.3s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=3, clf__n_estimators=269, clf__random_state=42; total time=   3.4s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=3, clf__n_estimators=269, clf__random_state=42; total time=   3.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=3, clf__n_estimators=269, clf__random_state=42; total time=   3.3s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=127, clf__random_state=42; total time=   2.1s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=127, clf__random_state=42; total time=   2.0s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=127, clf__random_state=42; total time=   2.4s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=4, clf__n_estimators=227, clf__random_state=42; total time=   4.4s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=4, clf__n_estimators=227, clf__random_state=42; total time=   4.4s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=4, clf__n_estimators=227, clf__random_state=42; total time=   4.5s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=4, clf__n_estimators=227, clf__random_state=42; total time=   4.7s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=4, clf__n_estimators=227, clf__random_state=42; total time=   4.8s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=7, clf__n_estimators=324, clf__random_state=42; total time=   5.7s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=7, clf__n_estimators=324, clf__random_state=42; total time=   5.7s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=7, clf__n_estimators=324, clf__random_state=42; total time=   4.6s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=7, clf__n_estimators=324, clf__random_state=42; total time=   4.8s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=7, clf__n_estimators=324, clf__random_state=42; total time=   5.1s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=332, clf__random_state=42; total time=   2.4s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=332, clf__random_state=42; total time=   2.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=332, clf__random_state=42; total time=   2.4s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=332, clf__random_state=42; total time=   2.2s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=332, clf__random_state=42; total time=   2.3s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=6, clf__n_estimators=324, clf__random_state=42; total time=   2.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=6, clf__n_estimators=324, clf__random_state=42; total time=   2.9s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=6, clf__n_estimators=324, clf__random_state=42; total time=   2.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=6, clf__n_estimators=324, clf__random_state=42; total time=   2.9s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=6, clf__n_estimators=324, clf__random_state=42; total time=   2.7s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=330, clf__random_state=42; total time=  39.8s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=151, clf__random_state=42; total time=   2.0s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=330, clf__random_state=42; total time=  39.1s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=330, clf__random_state=42; total time=  39.7s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=151, clf__random_state=42; total time=   2.0s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=330, clf__random_state=42; total time=  40.8s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=151, clf__random_state=42; total time=   2.1s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=330, clf__random_state=42; total time=  42.4s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=151, clf__random_state=42; total time=   2.1s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=151, clf__random_state=42; total time=   2.2s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=7, clf__n_estimators=259, clf__random_state=42; total time=  12.7s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=7, clf__n_estimators=259, clf__random_state=42; total time=  12.6s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=7, clf__n_estimators=259, clf__random_state=42; total time=  13.1s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=7, clf__n_estimators=259, clf__random_state=42; total time=  12.5s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=7, clf__n_estimators=259, clf__random_state=42; total time=  12.8s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=3, clf__n_estimators=319, clf__random_state=42; total time=   4.2s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=3, clf__n_estimators=319, clf__random_state=42; total time=   4.3s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=3, clf__n_estimators=319, clf__random_state=42; total time=   4.8s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=3, clf__n_estimators=319, clf__random_state=42; total time=   4.7s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=3, clf__n_estimators=319, clf__random_state=42; total time=   4.9s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=225, clf__random_state=42; total time=   3.3s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=225, clf__random_state=42; total time=   3.1s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=225, clf__random_state=42; total time=   3.1s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=225, clf__random_state=42; total time=   2.9s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=225, clf__random_state=42; total time=   2.9s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=7, clf__n_estimators=346, clf__random_state=42; total time=   3.2s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=6, clf__n_estimators=212, clf__random_state=42; total time=  17.3s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=7, clf__n_estimators=346, clf__random_state=42; total time=   3.4s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=7, clf__n_estimators=346, clf__random_state=42; total time=   3.2s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=6, clf__n_estimators=212, clf__random_state=42; total time=  17.4s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=7, clf__n_estimators=346, clf__random_state=42; total time=   3.2s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=4, clf__min_samples_split=7, clf__n_estimators=346, clf__random_state=42; total time=   3.3s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=6, clf__n_estimators=212, clf__random_state=42; total time=  17.2s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=6, clf__n_estimators=212, clf__random_state=42; total time=  17.4s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=6, clf__n_estimators=212, clf__random_state=42; total time=  17.5s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=7, clf__n_estimators=494, clf__random_state=42; total time=   4.7s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=7, clf__n_estimators=494, clf__random_state=42; total time=   4.8s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=7, clf__n_estimators=494, clf__random_state=42; total time=   4.8s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=7, clf__n_estimators=494, clf__random_state=42; total time=   4.5s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=7, clf__n_estimators=494, clf__random_state=42; total time=   4.4s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=425, clf__random_state=42; total time=   3.3s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=425, clf__random_state=42; total time=   3.4s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=425, clf__random_state=42; total time=   3.5s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=425, clf__random_state=42; total time=   3.6s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=425, clf__random_state=42; total time=   3.6s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=393, clf__random_state=42; total time=  31.8s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=393, clf__random_state=42; total time=  32.3s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=393, clf__random_state=42; total time=  33.4s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=393, clf__random_state=42; total time=  34.9s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=393, clf__random_state=42; total time=  35.7s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=227, clf__random_state=42; total time=  10.4s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=445, clf__random_state=42; total time=  32.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=227, clf__random_state=42; total time=  10.4s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=227, clf__random_state=42; total time=  10.4s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=445, clf__random_state=42; total time=  34.9s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=445, clf__random_state=42; total time=  33.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=227, clf__random_state=42; total time=  10.4s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=445, clf__random_state=42; total time=  36.1s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=227, clf__random_state=42; total time=  10.1s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=20, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=445, clf__random_state=42; total time=  37.2s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=250, clf__random_state=42; total time=  12.1s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=250, clf__random_state=42; total time=  12.2s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=250, clf__random_state=42; total time=  12.1s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=5, clf__n_estimators=243, clf__random_state=42; total time=  11.8s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=250, clf__random_state=42; total time=  12.6s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=2, clf__n_estimators=250, clf__random_state=42; total time=  12.1s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=4, clf__min_samples_split=4, clf__n_estimators=108, clf__random_state=42; total time=   1.6s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=3, clf__min_samples_split=5, clf__n_estimators=243, clf__random_state=42; total time=  12.1s
# ...
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=3, clf__n_estimators=134, clf__random_state=42; total time=   0.8s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=3, clf__n_estimators=134, clf__random_state=42; total time=   0.8s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=3, clf__n_estimators=134, clf__random_state=42; total time=   0.7s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=3, clf__n_estimators=134, clf__random_state=42; total time=   0.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=3, clf__n_estimators=189, clf__random_state=42; total time=   0.7s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=3, clf__n_estimators=189, clf__random_state=42; total time=   0.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=3, clf__n_estimators=189, clf__random_state=42; total time=   0.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=3, clf__n_estimators=189, clf__random_state=42; total time=   0.7s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=3, clf__n_estimators=189, clf__random_state=42; total time=   0.7s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=5, clf__n_estimators=413, clf__random_state=42; total time=   2.4s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=5, clf__n_estimators=413, clf__random_state=42; total time=   2.6s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=5, clf__n_estimators=413, clf__random_state=42; total time=   2.5s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=5, clf__n_estimators=413, clf__random_state=42; total time=   2.6s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=5, clf__n_estimators=413, clf__random_state=42; total time=   2.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=6, clf__n_estimators=496, clf__random_state=42; total time=  10.9s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=6, clf__n_estimators=496, clf__random_state=42; total time=  11.1s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=6, clf__n_estimators=496, clf__random_state=42; total time=  10.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=291, clf__random_state=42; total time=   1.0s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=6, clf__n_estimators=496, clf__random_state=42; total time=  10.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=291, clf__random_state=42; total time=   1.1s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=291, clf__random_state=42; total time=   1.1s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=195, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=10, clf__max_features=None, clf__min_samples_leaf=4, clf__min_samples_split=6, clf__n_estimators=496, clf__random_state=42; total time=  10.7s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=291, clf__random_state=42; total time=   1.0s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=291, clf__random_state=42; total time=   1.0s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=195, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=195, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=195, clf__random_state=42; total time=   0.7s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=8, clf__n_estimators=195, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=6, clf__n_estimators=378, clf__random_state=42; total time=   2.3s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=6, clf__n_estimators=378, clf__random_state=42; total time=   2.3s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=6, clf__n_estimators=378, clf__random_state=42; total time=   2.1s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=6, clf__n_estimators=378, clf__random_state=42; total time=   2.3s
# [CV] END clf__bootstrap=False, clf__class_weight=None, clf__max_depth=50, clf__max_features=sqrt, clf__min_samples_leaf=3, clf__min_samples_split=6, clf__n_estimators=378, clf__random_state=42; total time=   2.2s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=161, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=161, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=161, clf__random_state=42; total time=   0.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=161, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=161, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=118, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=118, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=118, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=118, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=False, clf__class_weight=balanced, clf__max_depth=None, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=118, clf__random_state=42; total time=   0.6s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=175, clf__random_state=42; total time=   0.8s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=175, clf__random_state=42; total time=   0.8s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=175, clf__random_state=42; total time=   0.8s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=175, clf__random_state=42; total time=   0.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=151, clf__random_state=42; total time=   0.4s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=4, clf__n_estimators=175, clf__random_state=42; total time=   0.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=151, clf__random_state=42; total time=   0.5s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=151, clf__random_state=42; total time=   0.5s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=316, clf__random_state=42; total time=   7.8s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=151, clf__random_state=42; total time=   0.4s
# [CV] END clf__bootstrap=True, clf__class_weight=None, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=3, clf__min_samples_split=9, clf__n_estimators=151, clf__random_state=42; total time=   0.4s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=316, clf__random_state=42; total time=   7.7s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=316, clf__random_state=42; total time=   7.8s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=316, clf__random_state=42; total time=   8.0s
# [CV] END clf__bootstrap=True, clf__class_weight=balanced, clf__max_depth=50, clf__max_features=None, clf__min_samples_leaf=1, clf__min_samples_split=9, clf__n_estimators=316, clf__random_state=42; total time=   7.8s
#
# == Best Random Forest Params ==
# {'clf__bootstrap': True, 'clf__class_weight': None, 'clf__max_depth': 20, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 4, 'clf__min_samples_split': 3, 'clf__n_estimators': 269, 'clf__random_state': 42}
# Best CV AUC (OvR): 0.6877
#
# == Random Forest — TEST Accuracy Report ==
# Accuracy: 0.3138
#               precision    recall  f1-score   support
#
#            0     0.3125    0.6250    0.4167        48
#            1     0.0000    0.0000    0.0000        31
#            2     0.0000    0.0000    0.0000        15
#            3     0.1061    0.1148    0.1102        61
#            4     0.0000    0.0000    0.0000        15
#            5     0.3259    0.3761    0.3492       117
#            6     0.2000    0.1818    0.1905        11
#            7     0.3333    0.2609    0.2927        46
#            8     0.0000    0.0000    0.0000        17
#            9     0.4138    0.4511    0.4317       133
#
#     accuracy                         0.3138       494
#    macro avg     0.1692    0.2010    0.1791       494
# weighted avg     0.2676    0.3138    0.2845       494
# /Users/morgancooper/data-science/MSDSResearchProjects/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/morgancooper/data-science/MSDSResearchProjects/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/morgancooper/data-science/MSDSResearchProjects/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Test Set AUC (OvR): 0.7373
#
# == Confidence Decile Table ==
#       Top %  N Samples  Correct Predictions  Accuracy in Decile  \
# 0   Top 10%         49                   32               0.653
# 1   Top 20%         98                   53               0.541
# 2   Top 30%        148                   71               0.480
# 3   Top 40%        197                   88               0.447
# 4   Top 50%        247                   97               0.393
# 5   Top 60%        296                  112               0.378
# 6   Top 70%        345                  126               0.365
# 7   Top 80%        395                  136               0.344
# 8   Top 90%        444                  145               0.327
# 9  Top 100%        494                  155               0.314
#
#    Avg Confidence
# 0           0.472
# 1           0.430
# 2           0.401
# 3           0.377
# 4           0.358
# 5           0.341
# 6           0.326
# 7           0.312
# 8           0.300
# 9           0.287
